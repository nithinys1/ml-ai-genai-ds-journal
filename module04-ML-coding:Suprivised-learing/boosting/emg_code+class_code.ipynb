# %%
# !gdown 19L3rYatfhbBL1r5MHrv-p_oM2wlvrhqk
# !gdown 1OHLKJwA3qZopKPvlKoRldM6BvA1A4dYF
# !gdown 1N7O_fWCTJLu8SIa_paKcDEzllgpMk8sK
# !gdown 12Bh2AN8LcZAlg20ehpQrEWccUDaSdsOG

import pickle
# Load data (deserialize)
with open('preprocessed_X_sm.pickle', 'rb') as handle:
    X_train = pickle.load(handle)

with open('X_test.pickle', 'rb') as handle:
    X_test = pickle.load(handle)

with open('y_sm.pickle', 'rb') as handle:
    y_train = pickle.load(handle)

with open('y_test.pickle', 'rb') as handle:
    y_test = pickle.load(handle)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19L3rYatfhbBL1r5MHrv-p_oM2wlvrhqk
# To: /content/preprocessed_X_sm.pickle
# 100% 534k/534k [00:00<00:00, 7.40MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1OHLKJwA3qZopKPvlKoRldM6BvA1A4dYF
# To: /content/X_test.pickle
# 100% 111k/111k [00:00<00:00, 4.20MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1N7O_fWCTJLu8SIa_paKcDEzllgpMk8sK
# To: /content/y_sm.pickle
# 100% 15.4k/15.4k [00:00<00:00, 52.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12Bh2AN8LcZAlg20ehpQrEWccUDaSdsOG
# To: /content/y_test.pickle
# 100% 9.49k/9.49k [00:00<00:00, 26.7MB/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1506230541.py in <cell line: 0>()
#       7 # Load data (deserialize)
#       8 with open('preprocessed_X_sm.pickle', 'rb') as handle:
# ----> 9     X_train = pickle.load(handle)
#      10
#      11 with open('X_test.pickle', 'rb') as handle:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in new_block(values, placement, ndim, refs)
#    2726     # - maybe_coerce_values already called/unnecessary
#    2727     klass = get_block_type(values.dtype)
# -> 2728     return klass(values, ndim=ndim, placement=placement, refs=refs)
#    2729
#    2730
#
# TypeError: Argument 'placement' has incorrect type (expected pandas._libs.internals.BlockPlacement, got numpy.ndarray)

# %%
import pandas as pd

X_train = pd.read_pickle("preprocessed_X_sm.pickle")
X_test  = pd.read_pickle("X_test.pickle")
y_train = pd.read_pickle("y_sm.pickle")
y_test  = pd.read_pickle("y_test.pickle")

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier(n_estimators=150, max_depth=2, loss = 'log_loss')

gbc.fit(X_train, y_train)

print(gbc.score(X_test, y_test))
# 0.8804347826086957

print(gbc.score(X_train, y_train))
# 0.948051948051948
# Out:
# 0.8804347826086957
# 0.948051948051948

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier(n_estimators=5, max_depth=2, loss = 'log_loss')

gbc.fit(X_train, y_train)

print(gbc.score(X_test, y_test))
# 0.8804347826086957

print(gbc.score(X_train, y_train))
# Out:
# 0.75
# 0.7765151515151515

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn

# !gdown 1h86M8si2YT-aI4Zec1MeMP_mPYsLPy5F

# x is extract

# !unrar x "./emg.rar" "./"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1h86M8si2YT-aI4Zec1MeMP_mPYsLPy5F
# To: /content/emg.rar
# 100% 18.6M/18.6M [00:00<00:00, 31.0MB/s]
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from ./emg.rar
#
# Creating    ./EMG Physical Action Data Set                            OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub1                       OK
# Creating    ./EMG Physical Action Data Set/sub1/Aggressive            OK
# Creating    ./EMG Physical Action Data Set/sub1/Aggressive/log        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub1/Aggressive/txt        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub1/Normal                OK
# Creating    ./EMG Physical Action Data Set/sub1/Normal/log            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub1/Normal/txt            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub2                       OK
# Creating    ./EMG Physical Action Data Set/sub2/Aggressive            OK
# Creating    ./EMG Physical Action Data Set/sub2/Aggressive/log        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub2/Aggressive/txt        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub2/Normal                OK
# Creating    ./EMG Physical Action Data Set/sub2/Normal/log            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub2/Normal/txt            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub3                       OK
# Creating    ./EMG Physical Action Data Set/sub3/Aggressive            OK
# Creating    ./EMG Physical Action Data Set/sub3/Aggressive/log        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub3/Aggressive/txt        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub3/Normal                OK
# Creating    ./EMG Physical Action Data Set/sub3/Normal/log            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub3/Normal/txt            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub4                       OK
# Creating    ./EMG Physical Action Data Set/sub4/Aggressive            OK
# Creating    ./EMG Physical Action Data Set/sub4/Aggressive/log        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub4/Aggressive/txt        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub4/Normal                OK
# Creating    ./EMG Physical Action Data Set/sub4/Normal/log            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ./EMG Physical Action Data Set/sub4/Normal/txt            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
# !sudo apt install tree
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (160 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tree.
# (Reading database ... 126435 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !tree "./EMG Physical Action Data Set/sub1"
# Out:
# ./EMG Physical Action Data Set/sub1
# ├── Aggressive
# │   ├── log
# │   │   ├── Elbowing.log
# │   │   ├── FrontKicking.log
# │   │   ├── Hamering.log
# │   │   ├── Headering.log
# │   │   ├── Kneeing.log
# │   │   ├── Pulling.log
# │   │   ├── Punching.log
# │   │   ├── Pushing.log
# │   │   ├── SideKicking.log
# │   │   └── Slapping.log
# │   └── txt
# │       ├── Elbowing.txt
# │       ├── Frontkicking.txt
# │       ├── Hamering.txt
# │       ├── Headering.txt
# │       ├── Kneeing.txt
# │       ├── Pulling.txt
# │       ├── Punching.txt
# │       ├── Pushing.txt
# │       ├── Sidekicking.txt
# │       └── Slapping.txt
# └── Normal
#     ├── log
#     │   ├── Bowing.log
#     │   ├── Clapping.log
#     │   ├── Handshaking.log
#     │   ├── Hugging.log
#     │   ├── Jumping.log
#     │   ├── Running.log
#     │   ├── Seating.log
#     │   ├── Standing.log
#     │   ├── Walking.log
#     │   └── Waving.log
#     └── txt
#         ├── Bowing.txt
#         ├── Clapping.txt
#         ├── Handshaking.txt
#         ├── Hugging.txt
#         ├── Jumping.txt
#         ├── Running.txt
#         ├── Seating.txt
#         ├── Standing.txt
#         ├── Walking.txt
#         └── Waving.txt
#
# 6 directories, 40 files

# %%
import pickle

# !gdown 171Yoe_GSapyrmOnD9oBzHWNOD_OnQs0F
# !gdown 1hnIlTPW3AMeB69EbeaXCRIrpMVT1Vwmc
# !gdown 1nZtB_RtxMg_MgoRczb8UWQX-AEK_l3qE
# !gdown 1zLDUErwKdmF-RacOyHEuI_z_46LssQtP


with open('X_train.pickle', 'rb') as handle:
    X_train = pickle.load(handle)

with open('X_test.pickle', 'rb') as handle:
    X_test = pickle.load(handle)

with open('Y_train.pickle', 'rb') as handle:
    y_train = pickle.load(handle)

with open('Y_test.pickle', 'rb') as handle:
    y_test = pickle.load(handle)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=171Yoe_GSapyrmOnD9oBzHWNOD_OnQs0F
# To: /content/Y_test.pickle
# 100% 31.7k/31.7k [00:00<00:00, 83.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1hnIlTPW3AMeB69EbeaXCRIrpMVT1Vwmc
# To: /content/X_test.pickle
# 100% 253k/253k [00:00<00:00, 4.80MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1nZtB_RtxMg_MgoRczb8UWQX-AEK_l3qE
# To: /content/Y_train.pickle
# 100% 126k/126k [00:00<00:00, 4.15MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1zLDUErwKdmF-RacOyHEuI_z_46LssQtP
# To: /content/X_train.pickle
# 100% 1.01M/1.01M [00:00<00:00, 10.8MB/s]

# %%
DTC with gridsearchcv

# %%
from sklearn.tree import DecisionTreeClassifier as DTC
from sklearn import tree
from sklearn.model_selection import GridSearchCV

params = {
    "max_depth" : [3, 5, 7, 10, 15],
    "max_leaf_nodes" : [20, 40, 60]
}

model1 = DTC()
clf = GridSearchCV(model1, params, scoring = "accuracy", cv=5)

clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [3, 5, 7, 10, 15],
#                          'max_leaf_nodes': [20, 40, 60]},
#              scoring='accuracy')

# %%
res = clf.cv_results_

for i in range(len(res["params"])):
  print(f"Parameters:{res['params'][i]} Mean_score: {res['mean_test_score'][i]} Rank: {res['rank_test_score'][i]}")
# Out:
# Parameters:{'max_depth': 3, 'max_leaf_nodes': 20} Mean_score: 0.34208509132931136 Rank: 13
# Parameters:{'max_depth': 3, 'max_leaf_nodes': 40} Mean_score: 0.34208509132931136 Rank: 13
# Parameters:{'max_depth': 3, 'max_leaf_nodes': 60} Mean_score: 0.34208509132931136 Rank: 13
# Parameters:{'max_depth': 5, 'max_leaf_nodes': 20} Mean_score: 0.44640960557136655 Rank: 12
# Parameters:{'max_depth': 5, 'max_leaf_nodes': 40} Mean_score: 0.4465364286531674 Rank: 11
# Parameters:{'max_depth': 5, 'max_leaf_nodes': 60} Mean_score: 0.446726703498857 Rank: 10
# Parameters:{'max_depth': 7, 'max_leaf_nodes': 20} Mean_score: 0.6326101441169556 Rank: 9
# Parameters:{'max_depth': 7, 'max_leaf_nodes': 40} Mean_score: 0.6348933014847713 Rank: 8
# Parameters:{'max_depth': 7, 'max_leaf_nodes': 60} Mean_score: 0.635210459746744 Rank: 7
# Parameters:{'max_depth': 10, 'max_leaf_nodes': 20} Mean_score: 0.6976794754761447 Rank: 5
# Parameters:{'max_depth': 10, 'max_leaf_nodes': 40} Mean_score: 0.773402086487067 Rank: 4
# Parameters:{'max_depth': 10, 'max_leaf_nodes': 60} Mean_score: 0.7897640941853448 Rank: 2
# Parameters:{'max_depth': 15, 'max_leaf_nodes': 20} Mean_score: 0.6976794754761447 Rank: 5
# Parameters:{'max_depth': 15, 'max_leaf_nodes': 40} Mean_score: 0.7794904390962618 Rank: 3
# Parameters:{'max_depth': 15, 'max_leaf_nodes': 60} Mean_score: 0.8032091106677196 Rank: 1

# %%
res
# Out:
# {'mean_fit_time': array([0.09463792, 0.09388528, 0.08498273, 0.12491803, 0.17780824,
#         0.13773665, 0.15212574, 0.16004248, 0.19472551, 0.24890089,
#         0.22881675, 0.20515108, 0.17279248, 0.18347144, 0.20271397]),
#  'std_fit_time': array([0.01212583, 0.01353952, 0.01524556, 0.01062129, 0.02331142,
#         0.02309667, 0.01758705, 0.0151147 , 0.04624799, 0.00761222,
#         0.03680568, 0.0269072 , 0.013906  , 0.01580583, 0.00927749]),
#  'mean_score_time': array([0.0045342 , 0.00318317, 0.00250096, 0.00427895, 0.00358243,
#         0.00247259, 0.00199666, 0.00239611, 0.00314331, 0.0029758 ,
#         0.00208416, 0.00204244, 0.00222893, 0.00168509, 0.00173407]),
#  'std_score_time': array([2.66599643e-03, 1.71298977e-03, 1.36618760e-03, 1.55335393e-03,
#         8.53372915e-04, 1.04184693e-03, 2.39870732e-04, 7.35944004e-04,
#         1.36205057e-03, 1.55180940e-03, 8.11068589e-04, 2.84187330e-04,
#         1.10857742e-03, 1.50566375e-04, 9.46952736e-05]),
#  'param_max_depth': masked_array(data=[3, 3, 3, 5, 5, 5, 7, 7, 7, 10, 10, 10, 15, 15, 15],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_max_leaf_nodes': masked_array(data=[20, 40, 60, 20, 40, 60, 20, 40, 60, 20, 40, 60, 20, 40,
#                     60],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False],
#         fill_value=999999),
#  'params': [{'max_depth': 3, 'max_leaf_nodes': 20},
#   {'max_depth': 3, 'max_leaf_nodes': 40},
#   {'max_depth': 3, 'max_leaf_nodes': 60},
#   {'max_depth': 5, 'max_leaf_nodes': 20},
#   {'max_depth': 5, 'max_leaf_nodes': 40},
#   {'max_depth': 5, 'max_leaf_nodes': 60},
#   {'max_depth': 7, 'max_leaf_nodes': 20},
#   {'max_depth': 7, 'max_leaf_nodes': 40},
#   {'max_depth': 7, 'max_leaf_nodes': 60},
#   {'max_depth': 10, 'max_leaf_nodes': 20},
#   {'max_depth': 10, 'max_leaf_nodes': 40},
#   {'max_depth': 10, 'max_leaf_nodes': 60},
#   {'max_depth': 15, 'max_leaf_nodes': 20},
#   {'max_depth': 15, 'max_leaf_nodes': 40},
#   {'max_depth': 15, 'max_leaf_nodes': 60}],
#  'split0_test_score': array([0.34147115, 0.34147115, 0.34147115, 0.43690552, 0.43753963,
#         0.43753963, 0.62809131, 0.63062777, 0.63031072, 0.70735574,
#         0.77425491, 0.79074192, 0.70735574, 0.78471782, 0.80976538]),
#  'split1_test_score': array([0.34654407, 0.34654407, 0.34654407, 0.44007609, 0.43944198,
#         0.43944198, 0.62555485, 0.62682308, 0.62682308, 0.68960051,
#         0.77013316, 0.78535193, 0.68960051, 0.7736208 , 0.80310717]),
#  'split2_test_score': array([0.34051997, 0.34051997, 0.34051997, 0.47558656, 0.47622067,
#         0.47653773, 0.64743183, 0.64965124, 0.64996829, 0.68611287,
#         0.77171845, 0.79296132, 0.68611287, 0.77488903, 0.79549778]),
#  'split3_test_score': array([0.34284808, 0.34284808, 0.34284808, 0.43958135, 0.43958135,
#         0.43989851, 0.63051062, 0.63273073, 0.63368221, 0.70282271,
#         0.77640343, 0.79384713, 0.70282271, 0.78052648, 0.80843641]),
#  'split4_test_score': array([0.33904218, 0.33904218, 0.33904218, 0.43989851, 0.43989851,
#         0.44021567, 0.6314621 , 0.63463368, 0.635268  , 0.70250555,
#         0.77450048, 0.78591817, 0.70250555, 0.78369807, 0.79923882]),
#  'mean_test_score': array([0.34208509, 0.34208509, 0.34208509, 0.44640961, 0.44653643,
#         0.4467267 , 0.63261014, 0.6348933 , 0.63521046, 0.69767948,
#         0.77340209, 0.78976409, 0.69767948, 0.77949044, 0.80320911]),
#  'std_test_score': array([0.00255149, 0.00255149, 0.00255149, 0.0146339 , 0.01486515,
#         0.01493442, 0.00768902, 0.0078213 , 0.0079308 , 0.00827563,
#         0.00221189, 0.00352442, 0.00827563, 0.00451062, 0.00539532]),
#  'rank_test_score': array([13, 13, 13, 12, 11, 10,  9,  8,  7,  5,  4,  2,  5,  3,  1],
#        dtype=int32)}

# %%
print(clf.best_estimator_)
# Out:
# DecisionTreeClassifier(max_depth=15, max_leaf_nodes=60)

# %%
clf = DTC(**clf.best_params_)

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=15, max_leaf_nodes=60)

# %%
clf.score(X_train, y_train)
# Out:
# 0.8223617453069508

# %%
clf.score(X_test, y_test)
# Out:
# 0.8125792543748415

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn import tree
from sklearn.model_selection import RandomizedSearchCV
import datetime as dt

params = {
    "n_estimators": [10,25,50,100,150,200],
    "max_depth" : [3, 5, 10, 15, 20],
    "max_leaf_nodes" : [20, 40, 80]
}

rfc = RFC(n_jobs = -1)
clf = RandomizedSearchCV(rfc, params, scoring = "accuracy", cv=3, n_jobs = -1, verbose = 1)

start = dt.datetime.now()
clf.fit(X_train, y_train)
end = dt.datetime.now()

res = clf.cv_results_

for i in range(len(res["params"])):
  print(f"Parameters:{res['params'][i]} Mean_score: {res['mean_test_score'][i]} Rank: {res['rank_test_score'][i]}")

print(f"Time taken for fits : {end - start}")

print(clf.best_estimator_)

rf = clf.best_estimator_

rf.fit(X_train, y_train)

print("Model acc",rf.score(X_test, y_test))
# Model acc 0.8934821202130357
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Parameters:{'n_estimators': 25, 'max_leaf_nodes': 20, 'max_depth': 3} Mean_score: 0.6211948249619482 Rank: 9
# Parameters:{'n_estimators': 10, 'max_leaf_nodes': 20, 'max_depth': 3} Mean_score: 0.5649416539827499 Rank: 10
# Parameters:{'n_estimators': 150, 'max_leaf_nodes': 20, 'max_depth': 5} Mean_score: 0.7733384069000507 Rank: 4
# Parameters:{'n_estimators': 25, 'max_leaf_nodes': 80, 'max_depth': 5} Mean_score: 0.7418188736681888 Rank: 7
# Parameters:{'n_estimators': 25, 'max_leaf_nodes': 80, 'max_depth': 10} Mean_score: 0.8784246575342465 Rank: 3
# Parameters:{'n_estimators': 50, 'max_leaf_nodes': 20, 'max_depth': 5} Mean_score: 0.7540588533739219 Rank: 6
# Parameters:{'n_estimators': 100, 'max_leaf_nodes': 20, 'max_depth': 5} Mean_score: 0.769533231861999 Rank: 5
# Parameters:{'n_estimators': 200, 'max_leaf_nodes': 20, 'max_depth': 3} Mean_score: 0.6839167935058347 Rank: 8
# Parameters:{'n_estimators': 150, 'max_leaf_nodes': 80, 'max_depth': 10} Mean_score: 0.8844495180111617 Rank: 2
# Parameters:{'n_estimators': 100, 'max_leaf_nodes': 80, 'max_depth': 20} Mean_score: 0.8903475393201421 Rank: 1
# Time taken for fits : 0:00:35.536885
# RandomForestClassifier(max_depth=20, max_leaf_nodes=80, n_jobs=-1)
# Model acc 0.8977935582044129

# %%
params = {
    "n_estimators": [50,100,150,200],
    "max_depth" : [3, 4, 5, 7],
    "max_leaf_nodes" : [20, 40, 80],
    "learning_rate": [0.1, 0.2, 0.3]
}

from sklearn.ensemble import GradientBoostingClassifier as GBC
from sklearn.model_selection import RandomizedSearchCV
import datetime as dt


gbc = GBC()
clf = RandomizedSearchCV(gbc, params, scoring = "accuracy", cv=3, n_jobs = -1, verbose = 1)

start = dt.datetime.now()

clf.fit(X_train, y_train)

end = dt.datetime.now()



res = clf.cv_results_

for i in range(len(res["params"])):
  print(f"Parameters:{res['params'][i]} Mean_score: {res['mean_test_score'][i]} Rank: {res['rank_test_score'][i]}")


print(f"Time taken for fits : {end - start}")
print(clf.best_estimator_)

gbc = clf.best_estimator_

gbc.fit(X_train, y_train)

print("Model acc",gbc.score(X_test, y_test))
# Model acc 0.9637331980725337
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Parameters:{'n_estimators': 150, 'max_leaf_nodes': 80, 'max_depth': 3, 'learning_rate': 0.2} Mean_score: 0.9367072552004059 Rank: 8
# Parameters:{'n_estimators': 200, 'max_leaf_nodes': 40, 'max_depth': 7, 'learning_rate': 0.2} Mean_score: 0.9604261796042618 Rank: 1
# Parameters:{'n_estimators': 50, 'max_leaf_nodes': 80, 'max_depth': 7, 'learning_rate': 0.2} Mean_score: 0.9479325215626586 Rank: 2
# Parameters:{'n_estimators': 100, 'max_leaf_nodes': 40, 'max_depth': 4, 'learning_rate': 0.3} Mean_score: 0.9427955352612888 Rank: 7
# Parameters:{'n_estimators': 100, 'max_leaf_nodes': 20, 'max_depth': 5, 'learning_rate': 0.1} Mean_score: 0.9442541856925418 Rank: 3
# Parameters:{'n_estimators': 100, 'max_leaf_nodes': 40, 'max_depth': 5, 'learning_rate': 0.1} Mean_score: 0.9438102486047691 Rank: 4
# Parameters:{'n_estimators': 50, 'max_leaf_nodes': 80, 'max_depth': 5, 'learning_rate': 0.1} Mean_score: 0.932521562658549 Rank: 9
# Parameters:{'n_estimators': 150, 'max_leaf_nodes': 20, 'max_depth': 4, 'learning_rate': 0.1} Mean_score: 0.9438102486047691 Rank: 4
# Parameters:{'n_estimators': 50, 'max_leaf_nodes': 40, 'max_depth': 4, 'learning_rate': 0.3} Mean_score: 0.9323313039066464 Rank: 10
# Parameters:{'n_estimators': 100, 'max_leaf_nodes': 20, 'max_depth': 4, 'learning_rate': 0.3} Mean_score: 0.9431760527650939 Rank: 6
# Time taken for fits : 0:43:04.953509
# GradientBoostingClassifier(learning_rate=0.2, max_depth=7, max_leaf_nodes=40,
#                            n_estimators=200)
# Model acc 0.9748922140502155

# %%
Time taken for fits : 0:59:52.610371

# %%
Accuracy: ~96.9%

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import StratifiedKFold

import datetime as dt

params = {
        "n_estimators": [50,100,150,200],
        "max_depth" : [3, 4, 5, 7],
        "learning_rate": [0.1, 0.2, 0.3],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        }
xgb = XGBClassifier(objective='multi:softmax', num_class=20, silent=True)


random_search = RandomizedSearchCV(xgb,
                                   param_distributions=params,
                                   n_iter=10,
                                   scoring='accuracy',
                                   n_jobs=-1,
                                   cv=3,
                                   verbose=2)


start = dt.datetime.now()
random_search.fit(X_train, y_train)
end = dt.datetime.now()

res = random_search.cv_results_

for i in range(len(res["params"])):
  print(f"Parameters:{res['params'][i]} Mean_score: {res['mean_test_score'][i]} Rank: {res['rank_test_score'][i]}")

print(f"Time taken for fits : {end - start}")

print(random_search.best_estimator_)

xgb = random_search.best_estimator_

xgb.fit(X_train, y_train)

print("Model acc",xgb.score(X_test, y_test))
# Model acc 0.9807253360385493
