# %% [markdown]
# ## Content
#
# - Recap
# - Shifting 2D lines
# - Proof of why weight vector is always perpendicular to the line or hyperplane
# - Distance between Origin and a line
#   - Algebra proof
#   - Geometric proof
# - Distance between Point and Line
#   - Algebra proof
#   - Geometric proof
# - Halfspaces

# %% [markdown]
# ## Recap
#
# > **Instructors note:**
# - Use scribbled notes to revise concepts covered in lecture 1 and 2

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/047/951/original/Screenshot_2023-09-12_at_6.19.39_PM.png?1694522994)

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/047/952/original/Screenshot_2023-09-12_at_6.20.25_PM.png?1694523041)

# %% [markdown]
# ## Shifting 2D lines
#
# > Instructors note:
# - Use desmos to help them understand what happens geometrically when we ask about shifting lines.
#   - Use this Demos link: https://www.desmos.com/calculator/vlrwndsxye
# - The goal here is to understand visually what happens when we are updating the weights and biases to find the best possible line that seperated our 2 class points.

# %% [markdown]
# **Note:**
# here we are working in the co-ordinate geometry space and not working with vectors

# %% [markdown]
# **Q. How to shift line by 'a' units to the right?**
# - First let's ensure that the line passes through the origing for that we'll make the bias term equal to 0
#
# **Points to remember:**
#
# **Note:** Here origin moving means position of origin with respect to the line
# - When shigting a line towards the right the origin moves towards left and if we shift the line to the left then the origin is moving to the right.
# - When shifting the line up our origin is moving down and when shifting line down our origin is moving up
# - Thus we can say that the origin is moving in the opposite direction to where we shift our line

# %% [markdown]
# **Let's see how to represent this mathematically**
#
# Q. When we are asked to shift a line to the right what will we change in the equation of line $w_1x_1+w_2x_2=w_0=0$ ?
# - Since the line is passing through origin and we want it to move towards the right let say by 20
# - we also know that when we move the line towards right the origin should be on the left side of the line
# - so what we'll be doing is we'll be moving origin by 20 units to the left which ensures that the origin is towards the left hand side of the line or we can also say that we are moving the line towards right.
# - thus the updated equation of the line is $w_1(x_1-20)+w_2x_2=w_0=0$
#
# **Always think of it as moving the origin and you'll not get confused.**
# - So whenever we say that we have sifted the line by 10 units to the right esentially we can say that we have shifted the origin towards left by 10 units.

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/047/953/original/Screenshot_2023-09-12_at_6.44.05_PM.png?1694524461)

# %% [markdown]
# Q. Now if we want to shif the above line towards left what will we do?
# - we'll simply add 20 instead of subtracting which ensures that the origin stays towards the right hand side of the line
# - Update equation of line is $w_1(x_1+20)+w_2x_2=w_0=0$

# %% [markdown]
# Lets visualize this instead of a number let's have a variable a such that we can now change the slider and see where the line is shifting
#
# Desmos Link: https://www.desmos.com/calculator/l4n0qwejjl

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/047/954/original/Screenshot_2023-09-12_at_6.49.28_PM.png?1694524780)

# %% [markdown]
# We can use the same logic to move the line up and down by a units

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/047/955/original/Screenshot_2023-09-12_at_6.53.31_PM.png?1694525025)

# %% [markdown]
# - if shifting the line to right or up we'll have either (x-a) or (y-a).
# - if shifting the line to left or down we'll have either (x+a) or (y+a).

# %% [markdown]
# **Q. Currently we have a line that is passing through the origin let say now i want to pass it through the point (10,10) what will be the equation of line?**
# - $w_1(x_1-10)+w_2(x_2-10)=w_0=0$
# - So here we are shifting the origin by 10 units towards left and then 10 units downards so that now the line passes throught the point (10,10)

# %% [markdown]
# Q. Now let's say that we have a line l1 which we have shited right by a units and up by b units getting us line l2, So what will the equation of this line be?
# - $w_1(x_1-a)+w_2(x_2-b)=w_0=0$
# - simplfying the equation we get
#   - $w_1x_1+w_2x_2-w1a-w2b+w_0=0$
#   - Here the term $-w1a-w2b+w_0$ is a constant which we can represent as $w_0'$

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/047/963/original/Screenshot_2023-09-12_at_7.11.48_PM.png?1694526123)

# %% [markdown]
# Let's understand why we learnt all the these

# %% [markdown]
# ## Proof of Weight vector is always perpendicular to the Line or any hyperplane

# %% [markdown]
# In the last class we said that the weight vector and the classifier(Line) are always perpedicular to each other now we want to prove this
#
# Let's say we have a line $w_1x_1+w_2x2+w_0=0$
# - we can represent the weight vector as [$w_1$,$w_2$]
# - Feature vector as [$x_1$,$x_2$]
# - Norm of weight vector would be $\left||w \right||$=$\sqrt{w_1^2+w_2^2}$

# %% [markdown]
# Now let's create a random weight vector starting at origin which need not be perpendicular to our line l1 as is represented as [$w_1$,$w_2$]
#
# Let's call the intersectinon of line and the weight vector as d which is represented as [$d_1$, $d_2$]
# - So from origin to the point d we call it as d vector
# - Norm of d vector is $\left||d \right||$=$\sqrt{d_1^2+d_2^2}$

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/013/original/Screenshot_2023-09-12_at_8.44.21_PM.png?1694531679)

# %% [markdown]
# **Q. Can we say that the point d is lying on the line L1?**
# - Yes
#
# **Q. which also means that it should satify the equation of the line L1?**
# - Yes it should
#
# **Q. Thus can we write the equation of line as $w_1d_1+w_2d_2+w_0=0$?**
# - Yes

# %% [markdown]
# **Q. How would you define the unit vector of weight vector?**
# - it is defined as $\frac{\bar{w}}{ \left||\bar{w} \right ||}$
#
# **Q. Can we say that vector d is in the direction of w?**
# - Yes
#
# **Q. Can we say that the d vector is some random constant 'k' times the weight vector w?**
# - Yes

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/021/original/Screenshot_2023-09-12_at_8.58.46_PM.png?1694532553)

# %% [markdown]
# Q. Can we write d in terms of w using the equation that we just studies?
# - Yes
# - It can be written as [$d_1$,$d_2$]= [$\frac{kw_1}{\left||w\right||}$,$\frac{kw_2}{\left||w\right||}$]
# - thus we can say that $d_1$=$\frac{kw_1}{\left||w\right||}$
# - $d_2$=$\frac{kw_2}{\left||w\right||}$

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/025/original/Screenshot_2023-09-12_at_9.04.13_PM.png?1694532893)

# %% [markdown]
# Q. Can we replace the new found values of $d_1$ and $d_2$?
# - Yes we can
# - thus after substituting the values in equation 2 we can solve for k as shown

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/025/original/Screenshot_2023-09-12_at_9.04.13_PM.png?1694532893)

# %% [markdown]
# Q. What do we call the point where the line intecepts the y axis?
# - Y intercept
#
# Q. How do we define the y-intecept in terms of $w_1$,$w_2$ and $w_0$?
# - (0, $-\frac{w_0}{w_2}$)
#
# Q. Can we define a vector which starts at the origin and goes uptill y-intercept?
# - Yes we can, and let's call this as y vector and is deinfed by points (0, $-\frac{w_0}{w_2}$)

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/028/original/Screenshot_2023-09-12_at_9.13.04_PM.png?1694533406)

# %% [markdown]
# Q. Now let's say we start at point d and go in the direction of vector y can we define this new vector let say x in terms of y and d?
# - Hint:
#   - Let say that you are in the canteen and now you want to go to the desk so there are 2 ways one is directly from cantee to office desk and other is you stop for chai break and then go to your office desk
#   - Since we are starting from same position and ending at same position in both the path we can use the vector addition rule here which is as shown below

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/033/original/Screenshot_2023-09-12_at_9.18.21_PM.png?1694533717)

# %% [markdown]
# So coming back to the original question how do we represent x vector in terms of y and d?
# - We can directly start at origin and go till the point of y-intercept of the line or we can take a detour and first go along the d vector and then the x vector to reach the same end point
# - thus we can say that $\bar{y}=\bar{d}+\bar{x}$
# - and using this we can say that $\bar{x}=\bar{y}-\bar{d}$
#
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/034/original/Screenshot_2023-09-12_at_9.23.08_PM.png?1694534005)

# %% [markdown]
# Using the equation of d vector and the value of k we can simplify it as follows

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/036/original/Screenshot_2023-09-12_at_9.27.03_PM.png?1694534242)

# %% [markdown]
# Lets compute the x vector which is vector y subtracted from vector d

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/038/original/Screenshot_2023-09-12_at_9.31.35_PM.png?1694534524)

# %% [markdown]
# Can we find angle between vector d and vector x ie vector (y-d)?
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/042/original/Screenshot_2023-09-12_at_9.47.15_PM.png?1694535448)

# %% [markdown]
# We can do that using the dot product between the 2 vectors which is
# $\bar{d}^T(\bar{y}-\bar{d})$ and after simplification what we are left with is 0

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/043/original/Screenshot_2023-09-12_at_9.49.30_PM.png?1694535587)

# %% [markdown]
# We have studied what the angle between 2 vector is thus we can see that
# $cos(\theta)=0$ and it is 0 at 90 degrees
# - hence we can say that the d vector which is in the direction of weight vector and the y-d vector which is in the direction of our line has a angle of 90 degrees thus
# - Thus we can conclude that the weight vector is perpendicular to our line

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/045/original/Screenshot_2023-09-12_at_9.55.48_PM.png?1694535964)

# %% [markdown]
# **Convey to learners:**
# - This is just to understand not asked in interviews
# - But from concept undersanding perspective it is a very important topic because later on we define any hyperplane using the weight vector also called as the norm, and we'd care less about the lines and only focus on this weight vectors

# %% [markdown]
# ## Distance between Origin and Line

# %% [markdown]
# Now given the line and the weight vector how would you find the distance from origin and line?
# - we need to find $\left||d\right||$
#
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/051/original/Screenshot_2023-09-12_at_10.48.02_PM.png?1694539139)

# %% [markdown]
# When we have a line in terms of Ax+By+C=0 we compute the distance as
# $\frac{C}{\sqrt{A^2+B^2}}$
#
# The formula for getting the distance is= $\frac{w_0}{\left||w\right||}$
#
# **Derivation of this is given as homework to you**
# - if learners ask please refer to the next screenshot

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/055/original/Screenshot_2023-09-12_at_11.07.53_PM.png?1694540289)

# %% [markdown]
# #### Algebra proof

# %% [markdown]
# Here we are re-using the d vectors defination to compute the norm of d which in turn will give us the distance between the line and the origin

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/059/original/Screenshot_2023-09-12_at_11.15.12_PM.png?1694540768)

# %% [markdown]
# #### Geometric proof

# %% [markdown]
# Problem Formulation
# - Suppose we have a line (blue) that denotes the decision boundary.
# - We kow that vector $w$ (red line) will be perpendicular to this blue line.
# - Now, we want to find the distance `d`

# %% [markdown]
# ![image](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/179/945/original/download_%282%29.png?1770882121)

# %% [markdown]
# Suppose we choose a random point on blue line: $x_0$
#
# From this random point, we draw a line (yellow) connecting to origin (0, 0)
#
# Let the angle between yellow and red line be $Θ$
#
# <br>
#
# We know the equation of blue line: $w^T x + w_0 = 0$
#
# Therefore point $x_0$ must satisfy this equation, as it is lying on this line: $w^T x_0 + w_0 = 0$
#
# i.e. $w^T x_0 = - w_0$
#
# <br>
#
# Also, we can evaluate the value of `d` using trigonometry as: $cos Θ = \frac{d}{||x_0||}$
# - where $||x_0||$ denotes the length of $x_0$ or it's distance from origin
#
# Therefore, $d = ||x_0|| cos Θ$

# %% [markdown]
# ![image](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/179/946/original/download_%283%29.png?1770882158)

# %% [markdown]
# > **What is $cos Θ$ in terms of $x_0$ and $w$?**
#
# We can see $x_0$ and $w$ in terms of vectors.
#
# Recall from last class we derived this to be
#
# $cos Θ = \frac{x^T_1 . x_2}{||x_1|| . ||x_2||}$
#
# Hence we can say that
#
# $cos Θ = \frac{w^T . x_0}{||w|| . ||x_0||}$

# %% [markdown]
# ![image](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/179/947/original/download_%284%29.png?1770882198)

# %% [markdown]
# Substituting this into equation of d,
#
# $d = ||x_0|| . \frac{w^T . x_0}{||w|| . ||x_0||} = \frac{w^T . x_0}{||w||}$
#
# <br>
#
# Substituting the value of $w^T x_0 = -w_0$
#
# We get: $d = \frac{-w_0}{||w||}$ ... (Equation 1)

# %% [markdown]
# ![image](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/179/949/original/download_%285%29.png?1770882255)

# %% [markdown]
# > **Why is the distance negative?**
#
# This sign indicates which side does the origin lies, with respect to the line $w^T.x + w_0 = 0$
#
# This makes sense also. By looking at the position of blue line and red line, we know from last lecture that value of $w_0$ has to be **negative**

# %% [markdown]
# ## **Distance between Point and a Line**

# %% [markdown]
# ##### Algebra proof

# %% [markdown]
# Let say we have a line and a point $x_0$ and we want to find out the distance between the point and the line?
# - First we'll create a vector going from origin to the point $x_0$
# - Now when we talk about the distance of a point from the line we always talk about th perpendicular distance let's call this perpendicular distance as vector d
# - and we also have out weight vector that is perpendicular to our line

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/056/original/Screenshot_2023-09-12_at_10.57.49_PM.png?1694540346)

# %% [markdown]
# Now using the shifting concept we studied earlier we can shift the origin to point $x_0$
#
# And now we can see that for the line the d vector will now act as the weight vector which is perpedicular to our Line.

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/057/original/Screenshot_2023-09-12_at_11.10.10_PM.png?1694540466)

# %% [markdown]
# Q. How do we represent the equation of line when we shift the line to point?
# - Let say that point $x_0$ is represented as ($x_0$,$y_0$)
# - Thus our equation would be $w_1(x_1+x_0)+w_2(x_2+y_0)+w_0=0$
# - After simpfying the equation and using the distance formula we can compute the distance d

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/058/original/Screenshot_2023-09-12_at_11.12.11_PM.png?1694540565)

# %% [markdown]
# Do you rememebr in you high school maths we looked at how to find the distance between a line and a point?
# - We esentially substitute the point in the equation of line and compute the distance

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/061/original/Screenshot_2023-09-12_at_11.19.47_PM.png?1694541017)

# %% [markdown]
# The one on the left is from the cordinate geometry perspective and the one on the right is using vector algebra, they both compute the same thing
#
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/062/original/Screenshot_2023-09-12_at_11.23.03_PM.png?1694541198)

# %% [markdown]
# By shifting the origin to the point $x_0$ we are esentially computing the distance between the new origin and the line which is nothing but the distance between the point $x_0$ and the line

# %% [markdown]
# ##### **Geometric proof**

# %% [markdown]
# So, consider we have a point $x_0$.
#
# We need to find the perpendicular distance between $x_0$ and the decision boundary (blue line).
#
# This distance is denoted as `d` (yellow line).

# %% [markdown]
# ![image](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/179/950/original/download_%286%29.png?1770882295)

# %% [markdown]
# Let's draw the $\vec{x_0}$ vector (i.e. root at origin, and tip at the point $x_0$)
#
# <br>
#
# We can see that this vector is getting intersected by the decision boundary.
#
# Let the length of each part be `p` and `q`, such that: $||x_0|| = p+q$ ... [Equation 2]
#
# <br>
#
# Also, we just proved above that perpendicular distance `A` between origin and decision boundary is: $A = \frac{-w_o}{||w||}$ .... [Equation 3]
#
# <br>
#
# We label the angle Θ as shown
#
# This gives us: $cos Θ = \frac{A}{p}$
#
# or, $p = \frac{A}{cos Θ}$ .... [Equation 4]
#
# <br>
#
# Also, note that the alternate angle will also be Θ, as they are formed by the same line across 2 parallell lines.
#
# This gives us: $cos Θ = \frac{d}{q}$
#
# or, $d = q . cos Θ$ .... [Equation 5]
#
# <br>
#
# Using equation 2, 4, and 4, we get:
#
# $q = ||x_0|| - p = ||x_0|| - \frac{A}{cos Θ}$

# %% [markdown]
# ![image](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/179/951/original/download_%287%29.png?1770882328)

# %% [markdown]
# Therefore substituting `q` : $d = ||x_0| cosΘ  - A$
#
# <br>
#
# Exanding this equation using 1 and 3,
#
# $d = ||x_0|| . (\frac{w^T.x_0}{||w|| . ||x_0||}) - (\frac{-w_0}{||w||})$
#
# <br>
#
# This gives us: $d = \frac{w^T x_0 + w_0}{||w||}$
#
# This relation is our key takeaway.

# %% [markdown]
# ![image](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/179/952/original/download_%288%29.png?1770882371)

# %% [markdown]
# ## Halfspaces

# %% [markdown]
# We saw that the line divided the given 2D space into 2 parts one on the left side and other on the right
# - Now when we are given a new point we need to find where does the point lie with respect to the line based on that we can tell which class data point does it belong to.

# %% [markdown]
# Q. How do we identify this mathematically?
# - We are going to use the weight vector
# - Points on the right side of the line or along the direction of weight vector we say that they belong to Positive half space
# - and points on the left side of the line or opposite to the direction of weight vector we say that they belong to negative half space.

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/064/original/Screenshot_2023-09-12_at_11.32.58_PM.png?1694541796)

# %% [markdown]
# Let's verify this
# - Let's take a scenario where in for the given 2 class classification problem we have a line with equation x=5 seperating them
# - Here the weight vector is along the x-axis
# - now for points that are on the right side of the line into the equation of line we will get a positive answer
#   - Eg. check for point (6,5)
#     - if we replace this in our equation of line we will get 6-5
#     - which is nothing but 1 which is a positive value
# - Now lets check for points that are to the left of our line
#   -Eg (2,3)
#     - When we substitute it into the equation of line we get 2-5
#     - which is -3 which is a negative value

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/048/068/original/Screenshot_2023-09-12_at_11.39.22_PM.png?1694542176)

# %% [markdown]
# This is one way of understanding the Positive and negative half spaces another way is using the conecpt of angles made by each poitns with the weight vector we'll look at this in the next class
